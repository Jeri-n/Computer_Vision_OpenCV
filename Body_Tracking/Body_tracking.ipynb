# %%
import cv2
import mediapipe as mp
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('E:\OCV\Body_Tracking\man_yoga.jpg')
plt.imshow(img)

# %%
mp_pose=mp.solutions.pose
pose_image=mp_pose.Pose(static_image_mode=True,min_detection_confidence=0.5) 
mp_drawing = mp.solutions.drawing_utils

# %%
def detectpose(image_pose,pose,draw=False,display=False):
    
    original_image=image_pose.copy()

    image_in_RGB =cv2.cvtColor(image_pose,cv2.COLOR_BGR2RGB)
    

    results=pose.process(image_in_RGB)

    if results.pose_landmarks and draw:
        mp_drawing.draw_landmarks(image=original_image,landmark_list=results.pose_landmarks,connections=mp_pose.POSE_CONNECTIONS)

    if display:

        plt.imshow(original_image[:,:,::-1])

# %%
img ='E:\OCV\Body_Tracking\man_yoga.jpg'
output=cv2.imread(img)
detectpose(output,pose_image,draw=True,display=True)
